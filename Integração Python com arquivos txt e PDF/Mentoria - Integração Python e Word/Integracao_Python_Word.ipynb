# %%
from docx import Document

# Criando o documento no Python
documento = Document()

# Edição do documento
faturamento = 1000

texto = f'''
Olá Lucas,

O faturamento da empresa ontem foi de R${faturamento:,.2f}

Tmj, abs.
'''
paragrafo = documento.add_paragraph(texto)

# %% [markdown]
# ### Formatação

# %%
from docx.shared import Pt, RGBColor, Cm
from docx.enum.style import WD_STYLE_TYPE

paragrafo.style = documento.styles.add_style('EstiloLucas', WD_STYLE_TYPE.PARAGRAPH)
paragrafo.style.font.name = 'Algerian'
paragrafo.style.font.size = Pt(15)
paragrafo.style.font.bold = True
paragrafo.style.font.italic = True
paragrafo.style.font.underline = True
paragrafo.style.font.color.rgb = RGBColor(255, 0, 0)

# %%
paragrafo = documento.add_paragraph('PS: A quantidade de produtos vendidos foi de 10', 'EstiloLucas')

# %%
# Implementando tudo que foi feito no Texto.docx
documento.save('Texto.docx')

# %% [markdown]
# ### Aproveitando um template do word

# %%
template = Document('template.docx')

# %%
paragrafo = template.add_paragraph('Contrato de Prestação de Serviço', 'NovoEstiloTeste')
template.save('NovoArquivo.docx')

# %% [markdown]
# ### Adicionar texto com edição dentro do texto

# %%
from docx import Document

# Criando o documento no Python
documento = Document()

# Edição do documento
faturamento = 1000

texto = f'''Olá Lucas,

O faturamento da empresa ontem foi de '''

texto_final = 'Tmj, abs.'

paragrafo = documento.add_paragraph(texto)

paragrafo.add_run(f'R${faturamento:,.2f}').bold = True

paragrafo = documento.add_paragraph(texto_final)

documento.save('Texto.docx')

# %% [markdown]
# ### Controle de Margem e Seções

# %%
from docx.enum.text import WD_PARAGRAPH_ALIGNMENT

# Criando o documento no Python
documento = Document()

for secao in documento.sections:
    secao.top_margin = Cm(0.5)
    secao.bottom_margin = Cm(1)
    secao.left_margin = Cm(1)
    secao.right_margin = Cm(1)

# Edição do documento
faturamento = 1000

texto = f'''
Olá Lucas,

O faturamento da empresa ontem foi de R${faturamento:,.2f}

Tmj, abs.
'''
paragrafo = documento.add_paragraph(texto)
paragrafo.alignment = WD_PARAGRAPH_ALIGNMENT.CENTER

documento.save('Texto.docx')

# %% [markdown]
# ### Inserir Imagem

# %%
# Criando o documento no Python
documento = Document()

for secao in documento.sections:
    secao.top_margin = Cm(0.5)
    secao.bottom_margin = Cm(1)
    secao.left_margin = Cm(1)
    secao.right_margin = Cm(1)

# Edição do documento
faturamento = 1000

texto = f'''
Olá Lucas,

O faturamento da empresa ontem foi de R${faturamento:,.2f}

Tmj, abs.
'''
paragrafo = documento.add_paragraph(texto)

documento.add_picture('imagem.png', width=Cm(4), height=Cm(4))

documento.save('Texto.docx')

# %% [markdown]
# ### Inserir Tabela

# %%
documento = Document()

records = (
    (3, '101', 'Spam'),
    (7, '422', 'Eggs'),
    (4, '631', 'Spam, spam, eggs, and spam')
)

table = documento.add_table(rows=1, cols=3, style='Light Grid Accent 1')
hdr_cells = table.rows[0].cells
hdr_cells[0].text = 'Qty'
hdr_cells[1].text = 'Id'
hdr_cells[2].text = 'Desc'
for qty, id, desc in records:
    row_cells = table.add_row().cells
    row_cells[0].text = str(qty)
    row_cells[1].text = id
    row_cells[2].text = desc
    
documento.save('Texto.docx')

# %% [markdown]
# ### Para verificar todos os estilos de um arquivo:

# %%
for estilo in documento.styles:
    print(estilo)
# Out:
# _ParagraphStyle('Normal') id: 2125924234048
# _ParagraphStyle('Header') id: 2125940945248
# <docx.styles.style._CharacterStyle object at 0x000001EEFBF47580>
# _ParagraphStyle('Footer') id: 2125924122192
# <docx.styles.style._CharacterStyle object at 0x000001EEFBF61820>
# _ParagraphStyle('Heading 1') id: 2125941052752
# _ParagraphStyle('Heading 2') id: 2125941051648
# _ParagraphStyle('Heading 3') id: 2125941054048
# _ParagraphStyle('Heading 4') id: 2125941054816
# _ParagraphStyle('Heading 5') id: 2125941054480
# _ParagraphStyle('Heading 6') id: 2125941051888
# _ParagraphStyle('Heading 7') id: 2125941051936
# _ParagraphStyle('Heading 8') id: 2125941053040
# _ParagraphStyle('Heading 9') id: 2125941053568
# <docx.styles.style._CharacterStyle object at 0x000001EEFBF61A90>
# _TableStyle('Normal Table') id: 2125941052608
# <docx.styles.style._NumberingStyle object at 0x000001EEFAC6A2E0>
# _ParagraphStyle('No Spacing') id: 2125941052992
# <docx.styles.style._CharacterStyle object at 0x000001EEFAE71D60>
# <docx.styles.style._CharacterStyle object at 0x000001EEFBF3C370>
# <docx.styles.style._CharacterStyle object at 0x000001EEFBF3C9D0>
# _ParagraphStyle('Title') id: 2125940900672
# <docx.styles.style._CharacterStyle object at 0x000001EEFBF3C250>
# _ParagraphStyle('Subtitle') id: 2125940901152
# <docx.styles.style._CharacterStyle object at 0x000001EEFBF3CD90>
# _ParagraphStyle('List Paragraph') id: 2125940900912
# _ParagraphStyle('Body Text') id: 2125940902688
# <docx.styles.style._CharacterStyle object at 0x000001EEFBF3CE50>
# _ParagraphStyle('Body Text 2') id: 2125940903744
# <docx.styles.style._CharacterStyle object at 0x000001EEFBF3C8B0>
# _ParagraphStyle('Body Text 3') id: 2125940902736
# <docx.styles.style._CharacterStyle object at 0x000001EEFBF3CF70>
# _ParagraphStyle('List') id: 2125940900144
# _ParagraphStyle('List 2') id: 2125940903408
# _ParagraphStyle('List 3') id: 2125940900192
# _ParagraphStyle('List Bullet') id: 2125940901584
# _ParagraphStyle('List Bullet 2') id: 2125940900528
# _ParagraphStyle('List Bullet 3') id: 2125940900096
# _ParagraphStyle('List Number') id: 2125920882896
# _ParagraphStyle('List Number 2') id: 2125920886736
# _ParagraphStyle('List Number 3') id: 2125920884864
# _ParagraphStyle('List Continue') id: 2125920883952
# _ParagraphStyle('List Continue 2') id: 2125920886448
# _ParagraphStyle('List Continue 3') id: 2125921406736
# _ParagraphStyle('macro') id: 2125921405344
# <docx.styles.style._CharacterStyle object at 0x000001EEFACA4760>
# _ParagraphStyle('Quote') id: 2125921406688
# <docx.styles.style._CharacterStyle object at 0x000001EEFACA4130>
# <docx.styles.style._CharacterStyle object at 0x000001EEFACA4970>
# <docx.styles.style._CharacterStyle object at 0x000001EEFACA42B0>
# <docx.styles.style._CharacterStyle object at 0x000001EEFACA4A00>
# <docx.styles.style._CharacterStyle object at 0x000001EEFACA4310>
# <docx.styles.style._CharacterStyle object at 0x000001EEFACA4E20>
# <docx.styles.style._CharacterStyle object at 0x000001EEFAF55A30>
# _ParagraphStyle('Caption') id: 2125924225904
# <docx.styles.style._CharacterStyle object at 0x000001EEFAF552E0>
# <docx.styles.style._CharacterStyle object at 0x000001EEFAF55DC0>
# _ParagraphStyle('Intense Quote') id: 2125924228304
# <docx.styles.style._CharacterStyle object at 0x000001EEFAF55400>
# <docx.styles.style._CharacterStyle object at 0x000001EEFAF55310>
# <docx.styles.style._CharacterStyle object at 0x000001EEFAF55F70>
# <docx.styles.style._CharacterStyle object at 0x000001EEFAF557C0>
# <docx.styles.style._CharacterStyle object at 0x000001EEFAF55220>
# <docx.styles.style._CharacterStyle object at 0x000001EEFAF55BB0>
# _ParagraphStyle('TOC Heading') id: 2125924225664
# _TableStyle('Table Grid') id: 2125924226192
# _TableStyle('Light Shading') id: 2125924225424
# _TableStyle('Light Shading Accent 1') id: 2125924225952
# _TableStyle('Light Shading Accent 2') id: 2125924226432
# _TableStyle('Light Shading Accent 3') id: 2125924226864
# _TableStyle('Light Shading Accent 4') id: 2125924225184
# _TableStyle('Light Shading Accent 5') id: 2125924227056
# _TableStyle('Light Shading Accent 6') id: 2125941018144
# _TableStyle('Light List') id: 2125941018096
# _TableStyle('Light List Accent 1') id: 2125941015168
# _TableStyle('Light List Accent 2') id: 2125941015840
# _TableStyle('Light List Accent 3') id: 2125941014688
# _TableStyle('Light List Accent 4') id: 2125941016992
# _TableStyle('Light List Accent 5') id: 2125941016896
# _TableStyle('Light List Accent 6') id: 2125941023744
# _TableStyle('Light Grid') id: 2125941026096
# _TableStyle('Light Grid Accent 1') id: 2125941025280
# _TableStyle('Light Grid Accent 2') id: 2125941025520
# _TableStyle('Light Grid Accent 3') id: 2125941026336
# _TableStyle('Light Grid Accent 4') id: 2125941023312
# _TableStyle('Light Grid Accent 5') id: 2125941023552
# _TableStyle('Light Grid Accent 6') id: 2125941025136
# _TableStyle('Medium Shading 1') id: 2125941023072
# _TableStyle('Medium Shading 1 Accent 1') id: 2125941022784
# _TableStyle('Medium Shading 1 Accent 2') id: 2125941024992
# _TableStyle('Medium Shading 1 Accent 3') id: 2125960776720
# _TableStyle('Medium Shading 1 Accent 4') id: 2125960773792
# _TableStyle('Medium Shading 1 Accent 5') id: 2125960776816
# _TableStyle('Medium Shading 1 Accent 6') id: 2125960775424
# _TableStyle('Medium Shading 2') id: 2125960775376
# _TableStyle('Medium Shading 2 Accent 1') id: 2125960775472
# _TableStyle('Medium Shading 2 Accent 2') id: 2125960777248
# _TableStyle('Medium Shading 2 Accent 3') id: 2125960775184
# _TableStyle('Medium Shading 2 Accent 4') id: 2125960774464
# _TableStyle('Medium Shading 2 Accent 5') id: 2125960774608
# _TableStyle('Medium Shading 2 Accent 6') id: 2125960774272
# _TableStyle('Medium List 1') id: 2125960774224
# _TableStyle('Medium List 1 Accent 1') id: 2125960773840
# _TableStyle('Medium List 1 Accent 2') id: 2125960775616
# _TableStyle('Medium List 1 Accent 3') id: 2125960777008
# _TableStyle('Medium List 1 Accent 4') id: 2125960775712
# _TableStyle('Medium List 1 Accent 5') id: 2125960777296
# _TableStyle('Medium List 1 Accent 6') id: 2125941022784
# _TableStyle('Medium List 2') id: 2125941026240
# _TableStyle('Medium List 2 Accent 1') id: 2125941022880
# _TableStyle('Medium List 2 Accent 2') id: 2125941023168
# _TableStyle('Medium List 2 Accent 3') id: 2125941025232
# _TableStyle('Medium List 2 Accent 4') id: 2125941024608
# _TableStyle('Medium List 2 Accent 5') id: 2125941025040
# _TableStyle('Medium List 2 Accent 6') id: 2125941023936
# _TableStyle('Medium Grid 1') id: 2125941025328
# _TableStyle('Medium Grid 1 Accent 1') id: 2125941022832
# _TableStyle('Medium Grid 1 Accent 2') id: 2125941024896
# _TableStyle('Medium Grid 1 Accent 3') id: 2125941016896
# _TableStyle('Medium Grid 1 Accent 4') id: 2125941014736
# _TableStyle('Medium Grid 1 Accent 5') id: 2125941016704
# _TableStyle('Medium Grid 1 Accent 6') id: 2125941015120
# _TableStyle('Medium Grid 2') id: 2125941015792
# _TableStyle('Medium Grid 2 Accent 1') id: 2125941017040
# _TableStyle('Medium Grid 2 Accent 2') id: 2125941015504
# _TableStyle('Medium Grid 2 Accent 3') id: 2125924225184
# _TableStyle('Medium Grid 2 Accent 4') id: 2125924228496
# _TableStyle('Medium Grid 2 Accent 5') id: 2125924225520
# _TableStyle('Medium Grid 2 Accent 6') id: 2125924226672
# _TableStyle('Medium Grid 3') id: 2125924228112
# _TableStyle('Medium Grid 3 Accent 1') id: 2125924226480
# _TableStyle('Medium Grid 3 Accent 2') id: 2125924227824
# _TableStyle('Medium Grid 3 Accent 3') id: 2125924226096
# _TableStyle('Medium Grid 3 Accent 4') id: 2125924227968
# _TableStyle('Medium Grid 3 Accent 5') id: 2125924229024
# _TableStyle('Medium Grid 3 Accent 6') id: 2125924225088
# _TableStyle('Dark List') id: 2125924226528
# _TableStyle('Dark List Accent 1') id: 2125924226624
# _TableStyle('Dark List Accent 2') id: 2125924227344
# _TableStyle('Dark List Accent 3') id: 2125924227392
# _TableStyle('Dark List Accent 4') id: 2125924227536
# _TableStyle('Dark List Accent 5') id: 2125924228400
# _TableStyle('Dark List Accent 6') id: 2125924227680
# _TableStyle('Colorful Shading') id: 2125941015744
# _TableStyle('Colorful Shading Accent 1') id: 2125941018144
# _TableStyle('Colorful Shading Accent 2') id: 2125941018096
# _TableStyle('Colorful Shading Accent 3') id: 2125941016368
# _TableStyle('Colorful Shading Accent 4') id: 2125941014880
# _TableStyle('Colorful Shading Accent 5') id: 2125941015360
# _TableStyle('Colorful Shading Accent 6') id: 2125941022976
# _TableStyle('Colorful List') id: 2125941025664
# _TableStyle('Colorful List Accent 1') id: 2125941023024
# _TableStyle('Colorful List Accent 2') id: 2125941023216
# _TableStyle('Colorful List Accent 3') id: 2125941024704
# _TableStyle('Colorful List Accent 4') id: 2125941025088
# _TableStyle('Colorful List Accent 5') id: 2125941025472
# _TableStyle('Colorful List Accent 6') id: 2125941024032
# _TableStyle('Colorful Grid') id: 2125941024800
# _TableStyle('Colorful Grid Accent 1') id: 2125941024656
# _TableStyle('Colorful Grid Accent 2') id: 2125941025568
# _TableStyle('Colorful Grid Accent 3') id: 2125941024992
# _TableStyle('Colorful Grid Accent 4') id: 2125924228400
# _TableStyle('Colorful Grid Accent 5') id: 2125924227632
# _TableStyle('Colorful Grid Accent 6') id: 2125924225904

# %% [markdown]
# ### Adaptar um documento

# %%
from datetime import datetime

contrato = Document('Contrato.docx')

nome = 'Lucas Marques'
item1 = 'Serviço de Treinamento em Excel'
item2 = 'Apostila Completa de Excel'
item3 = 'Serviço de Treinamentos de Python'


dicionario_valores = {
    'XXXX': nome,
    'YYYY': item1,
    'ZZZZ': item2,
    'WWWW': item3,
    'DD': str(datetime.now().day),
    'MM': str(datetime.now().month),
    'AAAA': str(datetime.now().year),
}

for paragrafo in contrato.paragraphs:
    # Para cada placeholder do dicionário
    for placeholder in dicionario_valores:
        if placeholder in paragrafo.text:
            paragrafo.text = paragrafo.text.replace(placeholder, dicionario_valores[placeholder])

contrato.save('Contrato Atualizado.docx')
